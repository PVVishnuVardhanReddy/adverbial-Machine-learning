# %%
pip install foolbox

# %%
import foolbox
import torch
import torchvision.models as models
from torchvision import transforms
import numpy as np
from PIL import Image

# %%
resnet18 = models.resnet18(pretrained=True).eval()
if torch.cuda.is_available():
      resnet18 = resnet18.cuda()
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
fmodel = foolbox.models.PyTorchModel(resnet18, bounds=(0, 1), preprocessing={'mean':mean,'std':std})

# %%
image, label = foolbox.utils.imagenet_example(data_format='channels_first')
image = image / 255.
print('predicted class', np.argmax(fmodel.predictions(image)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ead12e6e8fbe> in <cell line: 1>()
# ----> 1 image, label = foolbox.utils.imagenet_example(data_format='channels_first')
#       2 image = image / 255.
#       3 print('predicted class', np.argmax(fmodel.predictions(image)))
#
# AttributeError: module 'foolbox.utils' has no attribute 'imagenet_example'

# %%
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load and preprocess an example image from ImageNet
example_image = Image.open("/content/Screenshot 2024-04-03 at 10.02.24 PM.png")  # Replace "example_image.jpg" with your image file path
image_tensor = preprocess(example_image).unsqueeze(0)

# Create the Foolbox model
fmodel = foolbox.models.PyTorchModel(resnet18, bounds=(0, 1))

# Predict the class of the example image
predictions = fmodel.predictions(image_tensor)

# Get the predicted label
predicted_class = np.argmax(predictions)

print('predicted class:', predicted_class)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-d96c5a52bcd5> in <cell line: 10>()
#       8 # Load and preprocess an example image from ImageNet
#       9 example_image = Image.open("/content/Screenshot 2024-04-03 at 10.02.24 PM.png")  # Replace "example_image.jpg" with your image file path
# ---> 10 image_tensor = preprocess(example_image).unsqueeze(0)
#      11
#      12 # Create the Foolbox model
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
# ...

# %%
import torch
import numpy as np
from torchvision import models, transforms
from PIL import Image

# Load pretrained ResNet18 model
resnet18 = models.resnet18(pretrained=True).eval()

# Move model to GPU if available
if torch.cuda.is_available():
    resnet18 = resnet18.cuda()

# Preprocessing transformation
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load and preprocess example image
image = Image.open('/content/Screenshot 2024-04-03 at 10.02.24 PM.png')  # Replace 'example_image.jpg' with your image path
image = preprocess(image)
image = image.unsqueeze(0)  # Add batch dimension

# Predict class
if torch.cuda.is_available():
    image = image.cuda()

with torch.no_grad():
    output = resnet18(image)
    predicted_class = torch.argmax(output, dim=1)

print('Predicted class:', predicted_class.item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-4cf3b9e21323> in <cell line: 23>()
#      21 # Load and preprocess example image
#      22 image = Image.open('/content/Screenshot 2024-04-03 at 10.02.24 PM.png')  # Replace 'example_image.jpg' with your image path
# ---> 23 image = preprocess(image)
#      24 image = image.unsqueeze(0)  # Add batch dimension
#      25
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# ...

# %%
import torch
import numpy as np
from torchvision import models, transforms
from PIL import Image
resnet18 = models.resnet18(pretrained=True).eval()
if torch.cuda.is_available():
    resnet18 = resnet18.cuda()
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
image = Image.open('/content/Screenshot 2024-04-09 at 3.53.38 PM.png')
image = preprocess(image)
if image.shape[0] != 3:
    image = image[:3]
image = image.unsqueeze(0)
if torch.cuda.is_available():
    image = image.cuda()

with torch.no_grad():
    output = resnet18(image)
    predicted_class = torch.argmax(output, dim=1)

print('Predicted class:', predicted_class.item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-882f199cb5c1> in <cell line: 15>()
#      13 ])
#      14 image = Image.open('/content/Screenshot 2024-04-09 at 3.53.38 PM.png')
# ---> 15 image = preprocess(image)
#      16 if image.shape[0] != 3:
#      17     image = image[:3]
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
# ...

# %%
import torch
import numpy as np
from torchvision import models, transforms
from PIL import Image
from torchvision import transforms
from torchvision.transforms.functional import pad
# Load pretrained ResNet18 model
resnet18 = models.resnet18(pretrained=True).eval()

# Move model to GPU if available
if torch.cuda.is_available():
    resnet18 = resnet18.cuda()
padding = 10
pad_transform = transforms.Lambda(lambda x: pad(x, padding))
# Preprocessing transformation
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize image to 224x224
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Load and preprocess example image
image = Image.open('/content/Screenshot 2024-04-09 at 3.53.38 PM.png')
composed_transforms = transforms.Compose([
    pad_transform,
    preprocess,
])
transformed_image = composed_transforms(image)  # Replace 'example_image.jpg' with your image path
image = transformed_image.unsqueeze(0)  # Add batch dimension

# Predict class
if torch.cuda.is_available():
    image = image.cuda()

with torch.no_grad():
    output = resnet18(image)
    predicted_class = torch.argmax(output, dim=1)

print('Predicted class:', predicted_class.item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-21272d30bb1b> in <cell line: 27>()
#      25     preprocess,
#      26 ])
# ---> 27 transformed_image = composed_transforms(image)  # Replace 'example_image.jpg' with your image path
#      28 image = transformed_image.unsqueeze(0)  # Add batch dimension
#      29
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# ...

# %%
from torchvision import transforms
from torchvision.transforms.functional import pad
padding = 10
pad_transform = transforms.Lambda(lambda x: pad(x, padding))
other_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
composed_transforms = transforms.Compose([
    pad_transform,
    other_transforms,
])
transformed_image = composed_transforms(image)
